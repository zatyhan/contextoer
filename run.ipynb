# %%
import gensim.downloader as api
import nltk 
from nltk.corpus import words
from nltk.stem import WordNetLemmatizer

# %%
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import random

# %%
api.info()['models'].keys()
# Out:
# dict_keys(['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis'])

# %%
model = api.load("word2vec-google-news-300")

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_rus.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package floresta to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package ieer to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package indian to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\maxent_treebank_pos_tagger_tab.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nps_chat.zip.
# [nltk_data]    | Downloading package omw to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package paradigms to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pe08 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\perluniprops.zip.
# [nltk_data]    | Downloading package pil to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\porter_test.zip.
# [nltk_data]    | Downloading package ppattach to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package pros_cons to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package ptb to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package punkt to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package punkt_tab to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rslp to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package rte to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package tagsets to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets_json.zip.
# [nltk_data]    | Downloading package timit to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package verbnet to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet3.zip.
# [nltk_data]    | Downloading package webtext to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to C:\Users\Investment
# [nltk_data]    |     Officer\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
vocabs= list(map(str.lower, model.key_to_index.keys()))

lemmatizer= WordNetLemmatizer()

english_words= set(words.words())

filtered_words = [] # list of words that are in the model and is valid in the English language
for word in vocabs:
    lemma = lemmatizer.lemmatize(word, pos='n')

    if lemma == word in english_words:
        filtered_words.append(word)

# %%
len(filtered_words)
# Out:
# 112889

# %%
# store the embeddings of each word

import numpy as np
embeddings = np.stack([model[word] for word in filtered_words if word in model])
len(embeddings)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[205], line 4
#       1 # store the embeddings of each word
#       3 import numpy as np
# ----> 4 embeddings = np.stack([model[word] for word in filtered_words if word in model.lower()])
#       5 len(embeddings)
#
# AttributeError: 'KeyedVectors' object has no attribute 'lower'

# %%
# frequent_words = []
# for word in model.key_to_index:
#     if word in filtered_words:
#         frequency= model.get_vecattr(word, "count")
#         frequent_words.append((word, frequency))

# sorted_words= sorted(frequent_words, key= lambda x: x[1], reverse= True)
# sorted_words[:10]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[183], line 3
#       1 frequent_words = []
#       2 for word in model.key_to_index:
# ----> 3     if word in filtered_words:
#       4         frequency= model.get_vecattr(word, "count")
#       5         frequent_words.append((word, frequency))
#
# KeyboardInterrupt:

# %%
browser = Browser('chrome')
browser.visit('https://contexto.me/')

# %%
input = browser.find_by_name('word')
import time
for i in range(10):
    time.sleep(2)
    input.clear()
    random_word= random.choice(filtered_words[:200])
    input.type(random_word + Keys.ENTER)

# %%
order = browser.find_by_css(".current span")[1].text
print(order)
# Out:
# 1097

# %%
model.most_similar(positive=["human"], negative=["right"], topn=10)
# Out:
# [('papillomaviruses', 0.3866841793060303),
#  ('granulocytic', 0.38443881273269653),
#  ('recombinant', 0.38203176856040955),
#  ('beings', 0.37375375628471375),
#  ('humans', 0.35641035437583923),
#  ('iachr', 0.3511636257171631),
#  ('documented', 0.3497867286205292),
#  ('proteome', 0.34949353337287903),
#  ('non-human', 0.3484194278717041),
#  ('habitations', 0.3467484414577484)]

# %%
import random 

random_word= random.choice(list(model.key_to_index.keys()))
random_word
# Out:
# 'welders_plumbers'
